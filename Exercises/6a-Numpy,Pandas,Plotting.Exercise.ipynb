# %% [markdown]
# # Python Exercises - Numpy, Pandas & Plotting

# %% [markdown]
# ## Setup: import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Create a pandas dataframe that contains the following columns:
#
# Column Name | Values
# --- | ---
# A | 500 random numbers drawn from a normal distribution with mean 15 and standard deviation 5
# B | 500 equally spaced numbers between 1 and 50 (inclusive)
# C | 500 random integers drawn between 10 and 30 (inclusive)

# %%
df = pd.DataFrame({
    "A" : np.random.normal(15,5,500),
    "B" : np.linspace(1,50,500),
    "C" : np.random.randint(10,30,500),

})
df
# Out:
#              A          B   C
# 0    15.370631   1.000000  29
# 1    12.787552   1.098196  28
# 2    15.713508   1.196393  14
# 3    19.344681   1.294589  21
# 4    11.829737   1.392786  21
# ..         ...        ...  ..
# 495   9.395179  49.607214  14
# 496   9.461441  49.705411  18
# 497  18.051836  49.803607  20
# 498  22.695906  49.901804  27
# 499   8.125612  50.000000  28
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Calculate the mean of column A.

# %%
mean_A = df["A"].mean()
mean_A
# Out:
# np.float64(14.954965321063275)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Plot a histogram of column A. It should contain a vertical line at the mean. Make the figure size (10,5). Make sure to add axis labels and a legend for the mean.

# %%
n = int(500**(1/2))
plt.figure(figsize = (10,5))
plt.hist(df["A"],bins = n, edgecolor = "black")
plt.axvline(mean_A,color = "blue", label = "mean")
plt.xlabel("Column A")
plt.ylabel("Frequency")
plt.title("Title")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Create a line plot of the first 100 values in column C. Make sure to add axis labels.

# %%
plt.plot(df["C"].iloc[:100])
plt.xlabel("Index")
plt.ylabel("Column C")
plt.show()

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Create a new column, `D`, that contains 3 times the values in column `B` plus some random noise (`np.random.normal(0,10,500`).

# %%
df["D"] = 3*df["B"] + np.random.normal(0,10,500)
df
# Out:
#              A          B   C           D
# 0    15.370631   1.000000  29  -12.252536
# 1    12.787552   1.098196  28  -10.754661
# 2    15.713508   1.196393  14    2.861249
# 3    19.344681   1.294589  21   -0.735976
# 4    11.829737   1.392786  21    2.552220
# ..         ...        ...  ..         ...
# 495   9.395179  49.607214  14  138.156647
# 496   9.461441  49.705411  18  140.599092
# 497  18.051836  49.803607  20  148.561276
# 498  22.695906  49.901804  27  152.937538
# 499   8.125612  50.000000  28  143.099153
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Create a scatter plot with column `B` on the x-axis and column `D` on the y-axis.  Make sure to add axis labels.

# %%
plt.scatter(df["B"], df["D"])
plt.xlabel("B column")
plt.ylabel("D column")
plt.show()

# %% [markdown]
# ## **BONUS** (only if you have time)

# %% [markdown]
# Create a new column, `E`, that that contains 3 times the values in column `B` plus some random noise with a smaller standard deviation (`np.random.normal(0,3,500`).  Add the points you generated for column `E` to the scatterplot you created in #5. Use a different color and marker for these points and add a legend.

# %%
df["E"] = 3*df["B"] + np.random.normal(0,3,500)
df
# Out:
#              A          B   C           D           E
# 0    15.370631   1.000000  29  -12.252536    3.988099
# 1    12.787552   1.098196  28  -10.754661    2.925981
# 2    15.713508   1.196393  14    2.861249   -0.214037
# 3    19.344681   1.294589  21   -0.735976    5.740937
# 4    11.829737   1.392786  21    2.552220    3.495588
# ..         ...        ...  ..         ...         ...
# 495   9.395179  49.607214  14  138.156647  150.657809
# 496   9.461441  49.705411  18  140.599092  143.881415
# 497  18.051836  49.803607  20  148.561276  151.796219
# 498  22.695906  49.901804  27  152.937538  148.750791
# 499   8.125612  50.000000  28  143.099153  157.159594
#
# [500 rows x 5 columns]

# %%
plt.scatter(df["D"], df["B"])
plt.scatter(df["E"], df["B"],color = "pink")
plt.legend()
plt.ylabel("D & E column")
plt.xlabel("B column")
plt.title("graph")
plt.show()
# Out:
# /tmp/ipykernel_2510/4001283232.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
